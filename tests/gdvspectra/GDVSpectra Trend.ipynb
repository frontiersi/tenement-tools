# %% [markdown]
# # GDVSpectra Trend module tests

# %% [markdown]
# ## Globals

# %%
# set globals paths
FOLDER_MODULES = r'C:\Users\Lewis\Documents\GitHub\tenement-tools\modules'  
FOLDER_SHARED = r'C:\Users\Lewis\Documents\GitHub\tenement-tools\shared'
TEST_MODULE = r'C:\Users\Lewis\Documents\GitHub\tenement-tools\tests\code'
GRP_LYR_FILE = r'C:\Users\Lewis\Documents\GitHub\tenement-tools\arc\lyr\group_template.lyrx'

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
# imports
import os
import datetime
import random
import numpy as np
import xarray as xr
from IPython.utils import io

# import testing functions
sys.path.append(TEST_MODULE)
import test_funcs

# import full arcpy toolbox
arcpy.ImportToolbox(r"C:\Users\Lewis\Documents\GitHub\tenement-tools\arc\toolbox\tenement-tools-toolbox.pyt")
# Out:
# <module 'toolbox'>

# %% [markdown]
# ### Reload libraries

# %%
# if scripts change, reload
from importlib import reload
reload(test_funcs)
# Out:
# <module 'test_funcs' from 'C:\\Users\\Lewis\\Documents\\GitHub\\tenement-tools\\tests\\code\\test_funcs.py'>

# %% [markdown]
# ### Set data files and locations

# %%
# setup general io
input_folder = r'E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs'
output_folder = r'E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\outputs'

# temp nc file and temp mask nc file for use when breaking ncs, mask ncs
temp_nc = os.path.join(input_folder, 'temp_nc.nc')               # temp nc file for use when breaking ncs
temp_mask_nc = os.path.join(input_folder, 'temp_mask_nc.nc')     # temp nc file for use when breaking ncs

# setup landsat cubes paths
ls_cubes = [
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\dwer_1_ls_90_20_like_odc_agg.nc",     # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\dwer_1_ls_90_20_like_odc_nonagg.nc",  # done all
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\roy_1_ls_10_20_like_odc_agg.nc",      # done def  
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\roy_1_ls_10_20_like_odc_nonagg.nc",   # done all
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\tute_1_ls_10_20_like_odc_agg.nc",     # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\tute_1_ls_10_20_like_odc_nonagg.nc",  # done all
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\yandi_1_ls_90_20_like_odc_agg.nc",    # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\yandi_1_ls_90_20_like_odc_nonagg.nc"  # done def
]

# setup sentinel2 cubes paths
s2_cubes = [
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\dwer_1_s2_16_20_like_odc_agg.nc",     # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\dwer_1_s2_16_20_like_odc_nonagg.nc",  # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\roy_2_s2_16_21_like_odc_agg.nc",      # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\roy_2_s2_16_21_like_odc_nonagg.nc",   # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\tute_1_s2_18_20_like_odc_agg.nc",     # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\tute_1_s2_18_20_like_odc_nonagg.nc",  # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\yandi_2_s2_16_20_like_odc_agg.nc",    
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\yandi_2_s2_16_20_like_odc_nonagg.nc"  
]

# setup landsat cubes mask paths
ls_masks = [
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\dwer_1_ls_90_20_like_odc_mask.nc",  # done def  
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\roy_1_ls_10_20_like_odc_mask.nc",   # done def  
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\tute_1_ls_10_20_like_odc_mask.nc",  # done def 
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\yandi_1_ls_90_20_like_odc_mask.nc"  # done def 
]

# setup sentinel2 cubes mask paths
s2_masks = [
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\dwer_1_s2_16_20_like_odc_mask.nc",  # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\roy_2_s2_16_21_like_odc_mask.nc",   # done def
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\tute_1_s2_18_20_like_odc_mask.nc",  
    r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\yandi_2_s2_16_20_like_odc_mask.nc"
]

# %% [markdown]
# ### Set specific raw netcdf and shapefiles

# %%
# set top level netcdf and shapefile
nc_file = s2_cubes[3]
nc_mask_file = s2_masks[1]

# %% [markdown]
# ### Set up function to iterate corruptor and tests (without mask support)

# %%
def run_corruptors_through_tests(in_nc, nc_corrs, tests, verbose):
    """
    this func takes a path to nc file or raw sat imagery, a list of nc
    corruptor funcs and params, a list of test funcs and params. Each 
    nc corruptor func is iterated through, and for each corrupted nc, 
    each test in tests is applied to corrupted nc. verbose sets how
    much information is printed.
    """
    
    for nc_corr in nc_corrs:
        corr_name = nc_corr[0].__name__                   # name of current corruptor func
        corr_func, corr_params = nc_corr[0], nc_corr[1]   # pointer to corruptor func and dict of params

        # notify
        print('Corrupting NetCDF via: {}.\n'.format(corr_name) + '- ' * 30)

        # create temp nc and corrupt it with current corruptor
        if not verbose:
            with io.capture_output() as cap:
                test_funcs.create_temp_nc(in_nc=in_nc, out_nc=temp_nc)
        else:
            test_funcs.create_temp_nc(in_nc=in_nc, out_nc=temp_nc)

        # run current corruptor function
        try:
            corr_func(**corr_params)
        except Exception as e:    
            print(e)
            print('Corruptor did not have enough data to work with. Skipping.\n')

        # iter each test func and apply to current corrupt nc
        for test in tests:
            test_nc_name = corr_name + '_' + test[0]    # name of current test nc
            test_func, test_params = test[1], test[2]   # pointer to test func and dict of params
            test_msg = test[3]
            
            # notify of test message
            print(test_msg)

            # create output nc file path and name and update params for in/out paths
            out_nc_file = os.path.join(output_folder, test_nc_name)
            
            # remove output nc if exists
            if os.path.exists(out_nc_file):
                os.remove(out_nc_file)
            
            # update params
            test_params.update({'in_like_nc_file': temp_nc, 'out_nc_file': out_nc_file})

            # perform current test
            try:
                # notify
                print('Performing test: {}.'.format(test_nc_name))

                # perform test, provide prints if requested
                if not verbose:
                    with io.capture_output() as cap:
                        test_func(**test_params)
                else:
                    test_func(**test_params)
                    print('\n')

            except Exception as e:    
                print(e)

        # notify
        print('All tests applied to corruptor NetCDF.\n\n')

# %% [markdown]
# ### Set up function to iterate corruptor and tests (with mask support)

# %%
def run_corruptors_through_tests_with_mask(in_nc, in_mask_nc, nc_corrs, mask_corrs, tests, verbose):
    """
    this func takes a path to nc file or raw sat imagery, a list of nc
    corruptor funcs and params, a list of test funcs and params. Each 
    nc corruptor func is iterated through, and for each corrupted nc, 
    each test in tests is applied to corrupted nc. verbose sets how
    much information is printed. considers mask corruptors.
    """
    
    for nc_corr in nc_corrs:
        nc_corr_name = nc_corr[0].__name__                      # name of current corruptor func
        nc_corr_func, nc_corr_params = nc_corr[0], nc_corr[1]   # pointer to corruptor func and dict of params

        # notify
        print('Corrupting NetCDF via: {}.\n'.format(nc_corr_name) + '- ' * 30)

        # create temp nc and corrupt it with current corruptor
        if not verbose:
            with io.capture_output() as cap:
                test_funcs.create_temp_nc(in_nc=in_nc, out_nc=temp_nc)
        else:
            test_funcs.create_temp_nc(in_nc=in_nc, out_nc=temp_nc)

        # run current corruptor function
        try:
            nc_corr_func(**nc_corr_params)
        except Exception as e:    
            print(e)
            print('NetCDF Corruptor did not have enough data to work with. Skipping.\n')
            
        # now, we iterate each mask nc corruptor for this current corrupt nc!
        for mask_corr in mask_corrs:
            mask_corr_name = mask_corr[0].__name__                          # name of current corruptor func
            mask_corr_func, mask_corr_params = mask_corr[0], mask_corr[1]   # pointer to corruptor func and dict of params
            
            # notify
            print('Corrupting mask NetCDF via: {}.\n'.format(mask_corr_name) + '- ' * 30)
            
            # create temp nc and corrupt it with current corruptor
            if not verbose:
                with io.capture_output() as cap:
                    test_funcs.create_temp_nc(in_nc=in_mask_nc, out_nc=temp_mask_nc)
            else:
                test_funcs.create_temp_nc(in_nc=in_mask_nc, out_nc=temp_mask_nc)
            
            # run current corruptor function
            try:
                mask_corr_func(**mask_corr_params)
            except Exception as e:    
                print(e)
                print('Mask NetCDF Corruptor did not have enough data to work with. Skipping.\n')
            
            # iter each test func and apply to current corrupt nc with consideration to shape
            for test in tests:
                test_nc_name = nc_corr_name + '_' + test[0]    # name of current test nc
                test_func, test_params = test[1], test[2]      # pointer to test func and dict of params
                test_msg = test[3]

                # notify of test message
                print(test_msg)
                
                # create output nc file path and name and update params for in/out paths
                out_nc_file = os.path.join(output_folder, test_nc_name)

                # remove output nc if exists
                if os.path.exists(out_nc_file):
                    os.remove(out_nc_file)
                    
                # update params
                test_params.update({'in_like_nc_file': temp_nc, 'out_nc_file': out_nc_file, 'in_mask_nc_file': temp_mask_nc})

                # perform current test
                try:
                    # notify
                    print('Performing test: {}.'.format(test_nc_name))

                    # perform test, provide prints if requested
                    if not verbose:
                        with io.capture_output() as cap:
                            test_func(**test_params)
                    else:
                        test_func(**test_params)
                        print('\n')

                except Exception as e:    
                    print(e)

            # notify
            print('All tests applied to corruptor NetCDF.\n\n')

# %% [markdown]
# ### Set up netcdf corruptor functions

# %%
# these are numerous netcdf corruptors. feed a raw nc in, break it, output as temp nc
# comment out any that are irrelevant
# each of these uncommented will be fed through the tests below
def build_nc_corruptors(temp_nc):
    """
    each one of these is a unique netcdf corruptor functions and 
    associated parameters. 
    """
    
    # set up list
    cs = []

    # func: raw default dataset, no changes
    cs.append([test_funcs.nc_default, {'in_nc': temp_nc}])

    # func: remove x, y, time, spatial_ref coords
    #cs.append([test_funcs.remove_coord, {'in_nc': temp_nc, 'coord': 'x'}])
    #cs.append([test_funcs.remove_coord, {'in_nc': temp_nc, 'coord': 'y'}])
    cs.append([test_funcs.remove_coord, {'in_nc': temp_nc, 'coord': 'time'}])
    #cs.append([test_funcs.remove_coord, {'in_nc': temp_nc, 'coord': 'spatial_ref'}])

    #func: remove like band
    cs.append([test_funcs.remove_var, {'in_nc': temp_nc, 'var': 'like'}])

    #func: limit number of years in various combos
    #cs.append([test_funcs.limit_years, {'in_nc': temp_nc, 's_year': 2019, 'e_year': 2020}])
    #cs.append([test_funcs.limit_years, {'in_nc': temp_nc, 's_year': 1993, 'e_year': 2000}])
    #cs.append([test_funcs.limit_years, {'in_nc': temp_nc, 's_year': 2010, 'e_year': 2013}])

    #func: set all vars to nan
    cs.append([test_funcs.set_nc_vars_all_nan, {'in_nc': temp_nc}])

    #func: set all vars to zero
    cs.append([test_funcs.set_nc_vars_all_zero, {'in_nc': temp_nc}])

    #func: set all vars for 10 rand times to all nan
    cs.append([test_funcs.set_nc_vars_random_all_nan, {'in_nc': temp_nc, 'num': 2}])

    #func: strip all attrs from nc    
    #cs.append([test_funcs.strip_nc_attributes, {'in_nc': temp_nc}])

    #func: set vars in first and last time index to all nan
    cs.append([test_funcs.set_end_times_to_all_nan, {'in_nc': temp_nc}])

    #func: reduce whole nc to one random time slice
    #cs.append([test_funcs.reduce_to_one_scene, {'in_nc': temp_nc}])

    #func: remove crs attribute
    #cs.append([test_funcs.remove_crs_attr, {'in_nc': temp_nc}])

    #func: invalidate crs attribute
    #cs.append([test_funcs.invalidate_crs_attr, {'in_nc': temp_nc, 'crs_text': 'EPSG:4326'}])
    #cs.append([test_funcs.invalidate_crs_attr, {'in_nc': temp_nc, 'crs_text': ''}])

    #func: remove nodatavals attribute
    #cs.append([test_funcs.remove_nodatavals_attr, {'in_nc': temp_nc}])

    return cs

nc_corruptors = build_nc_corruptors(temp_nc=temp_nc)

# %% [markdown]
# ### Setup mask corruptor functions

# %%
# these are numerous mask nc corruptors. feed a raw shp in, break it, output as temp nc
# comment out any that are irrelevant
# each of these uncommented will be fed through some tests below
def build_mask_corruptors(temp_mask_nc):
    """
    each one of these is a unique netcdf corruptor functions and 
    associated parameters. 
    """
    
    # set up list
    cs = []

    # func: raw default dataset, no changes
    cs.append([test_funcs.nc_default, {'in_nc': temp_mask_nc}])
    
#     # func: remove x, y, time, spatial_ref coords
#     cs.append([test_funcs.remove_coord, {'in_nc': temp_mask_nc, 'coord': 'x'}])
#     cs.append([test_funcs.remove_coord, {'in_nc': temp_mask_nc, 'coord': 'y'}])
#     cs.append([test_funcs.remove_coord, {'in_nc': temp_mask_nc, 'coord': 'spatial_ref'}])

#     #func: remove thresh band vars
#     cs.append([test_funcs.remove_var, {'in_nc': temp_mask_nc, 'var': 'thresh'}])

#     #func: set all vars to nan
#     cs.append([test_funcs.set_nc_vars_all_nan, {'in_nc': temp_mask_nc}])

#     #func: set all vars to zero
#     cs.append([test_funcs.set_nc_vars_all_zero, {'in_nc': temp_mask_nc}])

#     #func: set all vars to ones
#     cs.append([test_funcs.set_nc_vars_all_ones, {'in_nc': temp_mask_nc}])

#     #func: strip all attrs from nc    
#     cs.append([test_funcs.strip_nc_attributes, {'in_nc': temp_mask_nc}])

#     #func: remove crs attribute
#     cs.append([test_funcs.remove_crs_attr, {'in_nc': temp_mask_nc}])

#     #func: invalidate crs attribute
#     cs.append([test_funcs.invalidate_crs_attr, {'in_nc': temp_mask_nc, 'crs_text': 'EPSG:4326'}])
#     cs.append([test_funcs.invalidate_crs_attr, {'in_nc': temp_mask_nc, 'crs_text': ''}])

#     #func: remove nodatavals attribute
#     cs.append([test_funcs.remove_nodatavals_attr, {'in_nc': temp_mask_nc}])

#     # func: shift dataset by coords
#     cs.append([test_funcs.shift_dataset_via_coords, {'in_nc': temp_mask_nc, 'x': 1300, 'y': 1500}])
#     cs.append([test_funcs.shift_dataset_via_coords, {'in_nc': temp_mask_nc, 'x': 15000, 'y': 15000}])

#     # func: reduce reslution
#     cs.append([test_funcs.reduce_resolution, {'in_nc': temp_mask_nc, 'factor': 3}])
    
#     # func: multiply values by a lot
#     cs.append([test_funcs.multiply_values, {'in_nc': temp_mask_nc, 'factor': 50}])    
    
    return cs

# %% [markdown]
# ## Run tests

# %% [markdown]
# ### Test One: Mask NetCDF

# %%
def build_test_one_funcs(in_nc, temp_nc):
    """sets up test one functions"""
    
    # set default params for tool
    inputs = {
        'in_like_nc_file': '',                # input like nc (i.e. temp nc)
        'in_mask_nc_file': '',                # input mask nc (i.e. temp mask nc)
        'out_nc_file': '',                    # output nc (i.e. t1a nc)
        'in_use_all_years': True,             # use all dates
        'in_start_year': None,                # from date
        'in_end_year': None,                  # to date
        'in_analysis_type': 'Mann-Kendall',   # trend method
        'in_mk_pvalue': 0.05,                 # man kendall pvalue
        'in_mk_direction': 'Both',            # man kendall trend direction
        'in_add_result_to_map': True,         # add result to map
    }
    
    # set up list
    ts = []

    # func: default like and mask ncs provided
    msg = 'Running Test One: default like nc with default mask input.'
    params = inputs.copy()
    ts.append(['t_1_def.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    return ts

# %% [markdown]
# ### Test One: Run!

# %%
# build lsit of nc corruptors and tests to iterate
nc_corrs = build_nc_corruptors(temp_nc)
mask_corrs = build_mask_corruptors(temp_mask_nc)
tests = build_test_one_funcs(in_nc=nc_file, temp_nc=temp_nc)

# run!
run_corruptors_through_tests_with_mask(nc_file, nc_mask_file, nc_corrs, mask_corrs, tests, verbose=False)
# Out:
# Corrupting NetCDF via: nc_default.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# No changes, setting up for default dataset.
# Corrupting mask NetCDF via: nc_default.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# No changes, setting up for default dataset.
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: remove_coord.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing coord: x
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF must have x, y coords.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: remove_coord.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing coord: y
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF must have x, y coords.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: remove_coord.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing coord: spatial_ref
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF must have a spatial_ref coord.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: remove_var.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing var: thresh
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: set_nc_vars_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting nc var data to all nan
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF "thresh" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: set_nc_vars_all_zero.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting nc var data to all zero
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF "thresh" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: set_nc_vars_all_ones.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting nc var data to all ones
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: strip_nc_attributes.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Stripping attributes from nc dim
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF attributes not found. NetCDF must have attributes.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: remove_crs_attr.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Stripping crs attribute from nc dim
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF CRS attribute not found. CRS required.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: invalidate_crs_attr.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Invalidating crs attribute from nc dim with: EPSG:4326
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF CRS is not EPSG:3577. EPSG:3577 required.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: invalidate_crs_attr.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Invalidating crs attribute from nc dim with:
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF CRS is not EPSG:3577. EPSG:3577 required.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: remove_nodatavals_attr.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Stripping nodatavals attribute from nc dim
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input mask NetCDF nodatavals attribute not found.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: shift_dataset_via_coords.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Shifting dataset x: 1300, y: 1500
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: shift_dataset_via_coords.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Shifting dataset x: 15000, y: 15000
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# Input datasets do not intersect.
# Could not intersect input datasets.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: reduce_resolution.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Reducing dataset resolution by factor of: 3
# Could not coarsen a dimension of size 827 with window 3
# Mask NetCDF Corruptor did not have enough data to work with. Skipping.
#
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# All tests applied to corruptor NetCDF.
#
#
# Corrupting mask NetCDF via: multiply_values.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Multiplyinh dataset by factor of: 50
# Running Test One: default like nc with default mask input.
# Performing test: nc_default_t_1_def.nc.
# All tests applied to corruptor NetCDF.

# %% [markdown]
# ### Test Two: From Date - To Date

# %%
def build_test_two_funcs(in_nc, temp_nc):
    """sets up test two functions"""
    
    # set default params for tool
    inputs = {
        'in_like_nc_file': '',                # input like nc (i.e. temp nc)
        'in_mask_nc_file': '',                # input mask nc (i.e. temp mask nc)
        'out_nc_file': '',                    # output nc (i.e. t1a nc)
        'in_use_all_years': False,            # use all dates
        'in_start_year': None,                # from date
        'in_end_year': None,                  # to date
        'in_analysis_type': 'Mann-Kendall',   # trend method
        'in_mk_pvalue': 0.05,                 # man kendall pvalue
        'in_mk_direction': 'Both',            # man kendall trend direction
        'in_add_result_to_map': True,         # add result to map
    }
    
    # set up list
    ts = []

    # func: default to and from dates without mask
    msg = 'Running Test Two: default in and to date without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': None, 'in_end_year': None})
    ts.append(['t_2_def.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # func: to and from dates manual string without mask
    msg = 'Running Test Two: in/to date manually set via string without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': '1990', 'in_end_year': '2020'})
    ts.append(['t_2_b.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])       
    
    # func: to and from dates dont exist in dataset without mask
    msg = 'Running Test Two: in/to date dont exist in dataset without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': 1989, 'in_end_year': 2023})
    ts.append(['t_2_c.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])     

    # func: to and from dates are a slice of dates in dataset without mask
    msg = 'Running Test Two: in/to date are 1995 to 2001 without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': 1995, 'in_end_year': 2001})
    ts.append(['t_2_d.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])  

    # func: to and from dates are a slice of dates in dataset without mask
    msg = 'Running Test Two: in/to date are 2011 to 2018 without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': 2011, 'in_end_year': 2018})
    ts.append(['t_2_e.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])  
    
    # func: to  date is higher than from date without mask
    msg = 'Running Test Two: in/to date are 2018 to 2009 without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': 2018, 'in_end_year': 2009})
    ts.append(['t_2_f.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])      

    # func: to date and from date are the same without mask
    msg = 'Running Test Two: in/to date are 2015 to 2015 without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': 2015, 'in_end_year': 2015})
    ts.append(['t_2_g.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])      

    # func: to date and from date are only one year without mask
    msg = 'Running Test Two: in/to date are inadequate three year 2015 to 2017 without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': 2015, 'in_end_year': 2016})
    ts.append(['t_2_h.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # func: to date and from date are only one year without mask
    msg = 'Running Test Two: in/to date has minimum four years 2015 to 2018 without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': 2015, 'in_end_year': 2018})
    ts.append(['t_2_i.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])    

    # try above with default mask nc now 
    inputs.update({'in_mask_nc_file': nc_mask_file})
    
    # func: default to and from dates with mask
    msg = 'Running Test Two: default in and to date with mask input.'
    params = inputs.copy()
    params.update({'in_start_year': None, 'in_end_year': None})
    ts.append(['t_2_j.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
        
    # func: to and from dates are a slice of dates in dataset with mask
    msg = 'Running Test Two: in/to date are 1995 to 2001 without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': 1995, 'in_end_year': 2001})
    ts.append(['t_2_k.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])  

    # func: to and from dates are a slice of dates in dataset with mask
    msg = 'Running Test Two: in/to date are 2016 to 2019 without mask input.'
    params = inputs.copy()
    params.update({'in_start_year': 2016, 'in_end_year': 2019})
    ts.append(['t_2_l.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg]) 
    
    return ts

# %% [markdown]
# ### Test Two: Run!

# %%
# build lsit of nc corruptors and tests to iterate
nc_corrs = build_nc_corruptors(temp_nc)
tests = build_test_two_funcs(in_nc=nc_file, temp_nc=temp_nc)

# run!
run_corruptors_through_tests(in_nc=nc_file, nc_corrs=nc_corrs, tests=tests, verbose=False)
# Out:
# Corrupting NetCDF via: nc_default.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# No changes, setting up for default dataset.
# Running Test Two: default in and to date without mask input.
# Performing test: nc_default_t_2_def.nc.
# Did not specify start and/or end years.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date manually set via string without mask input.
# Performing test: nc_default_t_2_b.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date dont exist in dataset without mask input.
# Performing test: nc_default_t_2_c.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: nc_default_t_2_d.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2011 to 2018 without mask input.
# Performing test: nc_default_t_2_e.nc.
# Running Test Two: in/to date are 2018 to 2009 without mask input.
# Performing test: nc_default_t_2_f.nc.
# Start year must be < end year.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2015 to 2015 without mask input.
# Performing test: nc_default_t_2_g.nc.
# Start year must be < end year.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are inadequate three year 2015 to 2017 without mask input.
# Performing test: nc_default_t_2_h.nc.
# Require 4 or more years of data.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date has minimum four years 2015 to 2018 without mask input.
# Performing test: nc_default_t_2_i.nc.
# Running Test Two: default in and to date with mask input.
# Performing test: nc_default_t_2_j.nc.
# Did not specify start and/or end years.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: nc_default_t_2_k.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2016 to 2019 without mask input.
# Performing test: nc_default_t_2_l.nc.
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: remove_coord.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing coord: time
# Running Test Two: default in and to date without mask input.
# Performing test: remove_coord_t_2_def.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date manually set via string without mask input.
# Performing test: remove_coord_t_2_b.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date dont exist in dataset without mask input.
# Performing test: remove_coord_t_2_c.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: remove_coord_t_2_d.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2011 to 2018 without mask input.
# Performing test: remove_coord_t_2_e.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2018 to 2009 without mask input.
# Performing test: remove_coord_t_2_f.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2015 to 2015 without mask input.
# Performing test: remove_coord_t_2_g.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are inadequate three year 2015 to 2017 without mask input.
# Performing test: remove_coord_t_2_h.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date has minimum four years 2015 to 2018 without mask input.
# Performing test: remove_coord_t_2_i.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: default in and to date with mask input.
# Performing test: remove_coord_t_2_j.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: remove_coord_t_2_k.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2016 to 2019 without mask input.
# Performing test: remove_coord_t_2_l.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: remove_var.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing var: like
# Running Test Two: default in and to date without mask input.
# Performing test: remove_var_t_2_def.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date manually set via string without mask input.
# Performing test: remove_var_t_2_b.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date dont exist in dataset without mask input.
# Performing test: remove_var_t_2_c.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: remove_var_t_2_d.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2011 to 2018 without mask input.
# Performing test: remove_var_t_2_e.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2018 to 2009 without mask input.
# Performing test: remove_var_t_2_f.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2015 to 2015 without mask input.
# Performing test: remove_var_t_2_g.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are inadequate three year 2015 to 2017 without mask input.
# Performing test: remove_var_t_2_h.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date has minimum four years 2015 to 2018 without mask input.
# Performing test: remove_var_t_2_i.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: default in and to date with mask input.
# Performing test: remove_var_t_2_j.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: remove_var_t_2_k.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2016 to 2019 without mask input.
# Performing test: remove_var_t_2_l.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_nc_vars_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting nc var data to all nan
# Running Test Two: default in and to date without mask input.
# Performing test: set_nc_vars_all_nan_t_2_def.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date manually set via string without mask input.
# Performing test: set_nc_vars_all_nan_t_2_b.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date dont exist in dataset without mask input.
# Performing test: set_nc_vars_all_nan_t_2_c.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: set_nc_vars_all_nan_t_2_d.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2011 to 2018 without mask input.
# Performing test: set_nc_vars_all_nan_t_2_e.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2018 to 2009 without mask input.
# Performing test: set_nc_vars_all_nan_t_2_f.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2015 to 2015 without mask input.
# Performing test: set_nc_vars_all_nan_t_2_g.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are inadequate three year 2015 to 2017 without mask input.
# Performing test: set_nc_vars_all_nan_t_2_h.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date has minimum four years 2015 to 2018 without mask input.
# Performing test: set_nc_vars_all_nan_t_2_i.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: default in and to date with mask input.
# Performing test: set_nc_vars_all_nan_t_2_j.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: set_nc_vars_all_nan_t_2_k.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2016 to 2019 without mask input.
# Performing test: set_nc_vars_all_nan_t_2_l.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_nc_vars_all_zero.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting nc var data to all zero
# Running Test Two: default in and to date without mask input.
# Performing test: set_nc_vars_all_zero_t_2_def.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date manually set via string without mask input.
# Performing test: set_nc_vars_all_zero_t_2_b.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date dont exist in dataset without mask input.
# Performing test: set_nc_vars_all_zero_t_2_c.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: set_nc_vars_all_zero_t_2_d.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2011 to 2018 without mask input.
# Performing test: set_nc_vars_all_zero_t_2_e.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2018 to 2009 without mask input.
# Performing test: set_nc_vars_all_zero_t_2_f.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2015 to 2015 without mask input.
# Performing test: set_nc_vars_all_zero_t_2_g.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are inadequate three year 2015 to 2017 without mask input.
# Performing test: set_nc_vars_all_zero_t_2_h.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date has minimum four years 2015 to 2018 without mask input.
# Performing test: set_nc_vars_all_zero_t_2_i.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: default in and to date with mask input.
# Performing test: set_nc_vars_all_zero_t_2_j.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: set_nc_vars_all_zero_t_2_k.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2016 to 2019 without mask input.
# Performing test: set_nc_vars_all_zero_t_2_l.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_nc_vars_random_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting 2 random times in nc var data to all nan
# ['2016-01-01T00:00:00.000000000' '2012-01-01T00:00:00.000000000']
# Running Test Two: default in and to date without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_def.nc.
# Did not specify start and/or end years.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date manually set via string without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_b.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date dont exist in dataset without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_c.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_d.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2011 to 2018 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_e.nc.
# Running Test Two: in/to date are 2018 to 2009 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_f.nc.
# Start year must be < end year.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2015 to 2015 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_g.nc.
# Start year must be < end year.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are inadequate three year 2015 to 2017 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_h.nc.
# Require 4 or more years of data.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date has minimum four years 2015 to 2018 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_i.nc.
# Running Test Two: default in and to date with mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_j.nc.
# Did not specify start and/or end years.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_k.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2016 to 2019 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_2_l.nc.
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_end_times_to_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting end times to all nan
# Running Test Two: default in and to date without mask input.
# Performing test: set_end_times_to_all_nan_t_2_def.nc.
# Did not specify start and/or end years.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date manually set via string without mask input.
# Performing test: set_end_times_to_all_nan_t_2_b.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date dont exist in dataset without mask input.
# Performing test: set_end_times_to_all_nan_t_2_c.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: set_end_times_to_all_nan_t_2_d.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2011 to 2018 without mask input.
# Performing test: set_end_times_to_all_nan_t_2_e.nc.
# Running Test Two: in/to date are 2018 to 2009 without mask input.
# Performing test: set_end_times_to_all_nan_t_2_f.nc.
# Start year must be < end year.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2015 to 2015 without mask input.
# Performing test: set_end_times_to_all_nan_t_2_g.nc.
# Start year must be < end year.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are inadequate three year 2015 to 2017 without mask input.
# Performing test: set_end_times_to_all_nan_t_2_h.nc.
# Require 4 or more years of data.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date has minimum four years 2015 to 2018 without mask input.
# Performing test: set_end_times_to_all_nan_t_2_i.nc.
# Running Test Two: default in and to date with mask input.
# Performing test: set_end_times_to_all_nan_t_2_j.nc.
# Did not specify start and/or end years.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 1995 to 2001 without mask input.
# Performing test: set_end_times_to_all_nan_t_2_k.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Two: in/to date are 2016 to 2019 without mask input.
# Performing test: set_end_times_to_all_nan_t_2_l.nc.
# All tests applied to corruptor NetCDF.

# %% [markdown]
# ### Test Three: Analysis Type

# %%
def build_test_three_funcs(in_nc, temp_nc):
    """sets up test three functions"""
    
    # set default params for tool
    inputs = {
        'in_like_nc_file': '',                # input like nc (i.e. temp nc)
        'in_mask_nc_file': '',                # input mask nc (i.e. temp mask nc)
        'out_nc_file': '',                    # output nc (i.e. t1a nc)
        'in_use_all_years': False,            # use all dates
        'in_start_year': None,                # from date
        'in_end_year': None,                  # to date
        'in_analysis_type': 'Mann-Kendall',   # trend method
        'in_mk_pvalue': 0.05,                 # man kendall pvalue
        'in_mk_direction': 'Both',            # man kendall trend direction
        'in_add_result_to_map': True,         # add result to map
    }
    
    # set up list
    ts = []

    # func: default analysis type without mask
    msg = 'Running Test Three: default analysis type (mann kendall) all dates without mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'Mann-Kendall', 'in_use_all_years': True})
    ts.append(['t_3_def.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: analysis type theilsen slope without mask
    msg = 'Running Test Three: analysis type theilsen slope all dates without mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'Theil-Sen Slope', 'in_use_all_years': True})
    ts.append(['t_3_a.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: analysis type theilsen slope without mask
    msg = 'Running Test Three: analysis type mann kendall spelt wrong without mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'Mankendal'})
    ts.append(['t_3_b.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # func: analysis type theilsen slope without mask
    msg = 'Running Test Three: analysis type Mann-Kendall 1995-1998 without mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'Mann-Kendall', 'in_start_year': 1995, 'in_end_year': 1998})
    ts.append(['t_3_c.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # func: analysis type theilsen slope without mask
    msg = 'Running Test Three: analysis type Theilsen Slope 2016-2020 without mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'Theil-Sen Slope', 'in_start_year': 2016, 'in_end_year': 2020})
    ts.append(['t_3_d.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # try above with default mask nc now 
    inputs.update({'in_mask_nc_file': nc_mask_file})
    
    # func: default analysis type without mask
    msg = 'Running Test Three: default analysis type (mann kendall) all dates with mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'Mann-Kendall', 'in_use_all_years': True})
    ts.append(['t_3_e.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: analysis type theilsen slope with mask
    msg = 'Running Test Three: analysis type theilsen slope all dates with mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'Theil-Sen Slope', 'in_use_all_years': True})
    ts.append(['t_3_f.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: analysis type theilsen slope with mask
    msg = 'Running Test Three: analysis type theil sen spelt wrong with mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'thiel sen'})
    ts.append(['t_3_g.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # func: analysis type theilsen slope with mask
    msg = 'Running Test Three: analysis type Mann-Kendall 2001-2004 with mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'Mann-Kendall', 'in_start_year': 2001, 'in_end_year': 2004})
    ts.append(['t_3_h.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # func: analysis type theilsen slope with mask
    msg = 'Running Test Three: analysis type Theilsen Slope 1990-1994 with mask input.'
    params = inputs.copy()
    params.update({'in_analysis_type': 'Theil-Sen Slopee', 'in_start_year': 1990, 'in_end_year': 1994})
    ts.append(['t_3_i.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    
    return ts

# %% [markdown]
# ### Test Three: Run!

# %%
# build lsit of nc corruptors and tests to iterate
nc_corrs = build_nc_corruptors(temp_nc)
tests = build_test_three_funcs(in_nc=nc_file, temp_nc=temp_nc)

# run!
run_corruptors_through_tests(in_nc=nc_file, nc_corrs=nc_corrs, tests=tests, verbose=False)
# Out:
# Corrupting NetCDF via: nc_default.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# No changes, setting up for default dataset.
# Running Test Three: default analysis type (mann kendall) all dates without mask input.
# Performing test: nc_default_t_3_def.nc.
# Running Test Three: analysis type theilsen slope all dates without mask input.
# Performing test: nc_default_t_3_a.nc.
# Running Test Three: analysis type mann kendall spelt wrong without mask input.
# Performing test: nc_default_t_3_b.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 1995-1998 without mask input.
# Performing test: nc_default_t_3_c.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 2016-2020 without mask input.
# Performing test: nc_default_t_3_d.nc.
# Running Test Three: default analysis type (mann kendall) all dates with mask input.
# Performing test: nc_default_t_3_e.nc.
# Running Test Three: analysis type theilsen slope all dates with mask input.
# Performing test: nc_default_t_3_f.nc.
# Running Test Three: analysis type theil sen spelt wrong with mask input.
# Performing test: nc_default_t_3_g.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 2001-2004 with mask input.
# Performing test: nc_default_t_3_h.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 1990-1994 with mask input.
# Performing test: nc_default_t_3_i.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: remove_coord.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing coord: time
# Running Test Three: default analysis type (mann kendall) all dates without mask input.
# Performing test: remove_coord_t_3_def.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theilsen slope all dates without mask input.
# Performing test: remove_coord_t_3_a.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type mann kendall spelt wrong without mask input.
# Performing test: remove_coord_t_3_b.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 1995-1998 without mask input.
# Performing test: remove_coord_t_3_c.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 2016-2020 without mask input.
# Performing test: remove_coord_t_3_d.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: default analysis type (mann kendall) all dates with mask input.
# Performing test: remove_coord_t_3_e.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theilsen slope all dates with mask input.
# Performing test: remove_coord_t_3_f.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theil sen spelt wrong with mask input.
# Performing test: remove_coord_t_3_g.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 2001-2004 with mask input.
# Performing test: remove_coord_t_3_h.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 1990-1994 with mask input.
# Performing test: remove_coord_t_3_i.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: remove_var.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing var: like
# Running Test Three: default analysis type (mann kendall) all dates without mask input.
# Performing test: remove_var_t_3_def.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theilsen slope all dates without mask input.
# Performing test: remove_var_t_3_a.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type mann kendall spelt wrong without mask input.
# Performing test: remove_var_t_3_b.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 1995-1998 without mask input.
# Performing test: remove_var_t_3_c.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 2016-2020 without mask input.
# Performing test: remove_var_t_3_d.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: default analysis type (mann kendall) all dates with mask input.
# Performing test: remove_var_t_3_e.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theilsen slope all dates with mask input.
# Performing test: remove_var_t_3_f.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theil sen spelt wrong with mask input.
# Performing test: remove_var_t_3_g.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 2001-2004 with mask input.
# Performing test: remove_var_t_3_h.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 1990-1994 with mask input.
# Performing test: remove_var_t_3_i.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_nc_vars_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting nc var data to all nan
# Running Test Three: default analysis type (mann kendall) all dates without mask input.
# Performing test: set_nc_vars_all_nan_t_3_def.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theilsen slope all dates without mask input.
# Performing test: set_nc_vars_all_nan_t_3_a.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type mann kendall spelt wrong without mask input.
# Performing test: set_nc_vars_all_nan_t_3_b.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 1995-1998 without mask input.
# Performing test: set_nc_vars_all_nan_t_3_c.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 2016-2020 without mask input.
# Performing test: set_nc_vars_all_nan_t_3_d.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
# Running Test Three: default analysis type (mann kendall) all dates with mask input.
# Performing test: set_nc_vars_all_nan_t_3_e.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theilsen slope all dates with mask input.
# Performing test: set_nc_vars_all_nan_t_3_f.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theil sen spelt wrong with mask input.
# Performing test: set_nc_vars_all_nan_t_3_g.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 2001-2004 with mask input.
# Performing test: set_nc_vars_all_nan_t_3_h.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 1990-1994 with mask input.
# Performing test: set_nc_vars_all_nan_t_3_i.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_nc_vars_all_zero.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting nc var data to all zero
# Running Test Three: default analysis type (mann kendall) all dates without mask input.
# Performing test: set_nc_vars_all_zero_t_3_def.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theilsen slope all dates without mask input.
# Performing test: set_nc_vars_all_zero_t_3_a.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type mann kendall spelt wrong without mask input.
# Performing test: set_nc_vars_all_zero_t_3_b.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 1995-1998 without mask input.
# Performing test: set_nc_vars_all_zero_t_3_c.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 2016-2020 without mask input.
# Performing test: set_nc_vars_all_zero_t_3_d.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: default analysis type (mann kendall) all dates with mask input.
# Performing test: set_nc_vars_all_zero_t_3_e.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theilsen slope all dates with mask input.
# Performing test: set_nc_vars_all_zero_t_3_f.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type theil sen spelt wrong with mask input.
# Performing test: set_nc_vars_all_zero_t_3_g.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 2001-2004 with mask input.
# Performing test: set_nc_vars_all_zero_t_3_h.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 1990-1994 with mask input.
# Performing test: set_nc_vars_all_zero_t_3_i.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_nc_vars_random_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting 2 random times in nc var data to all nan
# ['2020-01-01T00:00:00.000000000' '2017-01-01T00:00:00.000000000']
# Running Test Three: default analysis type (mann kendall) all dates without mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_def.nc.
# Running Test Three: analysis type theilsen slope all dates without mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_a.nc.
# Running Test Three: analysis type mann kendall spelt wrong without mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_b.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 1995-1998 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_c.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 2016-2020 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_d.nc.
# Running Test Three: default analysis type (mann kendall) all dates with mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_e.nc.
# Running Test Three: analysis type theilsen slope all dates with mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_f.nc.
# Running Test Three: analysis type theil sen spelt wrong with mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_g.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 2001-2004 with mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_h.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 1990-1994 with mask input.
# Performing test: set_nc_vars_random_all_nan_t_3_i.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_end_times_to_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting end times to all nan
# Running Test Three: default analysis type (mann kendall) all dates without mask input.
# Performing test: set_end_times_to_all_nan_t_3_def.nc.
# Running Test Three: analysis type theilsen slope all dates without mask input.
# Performing test: set_end_times_to_all_nan_t_3_a.nc.
# Running Test Three: analysis type mann kendall spelt wrong without mask input.
# Performing test: set_end_times_to_all_nan_t_3_b.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 1995-1998 without mask input.
# Performing test: set_end_times_to_all_nan_t_3_c.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 2016-2020 without mask input.
# Performing test: set_end_times_to_all_nan_t_3_d.nc.
# Running Test Three: default analysis type (mann kendall) all dates with mask input.
# Performing test: set_end_times_to_all_nan_t_3_e.nc.
# Running Test Three: analysis type theilsen slope all dates with mask input.
# Performing test: set_end_times_to_all_nan_t_3_f.nc.
# Running Test Three: analysis type theil sen spelt wrong with mask input.
# Performing test: set_end_times_to_all_nan_t_3_g.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Mann-Kendall 2001-2004 with mask input.
# Performing test: set_end_times_to_all_nan_t_3_h.nc.
# Start year is not in likelihood NetCDF.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Three: analysis type Theilsen Slope 1990-1994 with mask input.
# Performing test: set_end_times_to_all_nan_t_3_i.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Mann-Kendall | Theil-Sen Slope.
# Failed to execute (GDVSpectra_Trend).
# All tests applied to corruptor NetCDF.

# %% [markdown]
# ### Test Four:  Mann-Kendall P-Value

# %%
def build_test_four_funcs(in_nc, temp_nc):
    """sets up test four functions"""
    
    # set default params for tool
    inputs = {
        'in_like_nc_file': '',                # input like nc (i.e. temp nc)
        'in_mask_nc_file': '',                # input mask nc (i.e. temp mask nc)
        'out_nc_file': '',                    # output nc (i.e. t1a nc)
        'in_use_all_years': True,             # use all dates
        'in_start_year': None,                # from date
        'in_end_year': None,                  # to date
        'in_analysis_type': 'Mann-Kendall',   # trend method
        'in_mk_pvalue': 0.05,                 # man kendall pvalue
        'in_mk_direction': 'Both',            # man kendall trend direction
        'in_add_result_to_map': True,         # add result to map
    }
    
    # set up list
    ts = []

    # func: default mk pvalue (0.05) without mask
    msg = 'Running Test Four: default mann kendall pvalue 0.05 without mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 0.05})
    ts.append(['t_4_def.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: min mk pvalue (0.001) without mask
    msg = 'Running Test Four: min mann kendall pvalue 0.001 without mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 0.001})
    ts.append(['t_4_a.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: max mk pvalue (0.5) without mask
    msg = 'Running Test Four: max mann kendall pvalue 0.5 without mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 0.5})
    ts.append(['t_4_b.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # func: max mk pvalue (0.1) without mask
    msg = 'Running Test Four: mann kendall pvalue 0.1 without mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 0.1})
    ts.append(['t_4_c.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: mk pvalue outside allowed without mask
    msg = 'Running Test Four: mann kendall pvalue 10.0 without mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 10.0})
    ts.append(['t_4_d.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])    

    # func: mk pvalue outside allowed without mask
    msg = 'Running Test Four: mann kendall pvalue 0.0 without mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 0.0})
    ts.append(['t_4_e.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # func: mk pvalue outside allowed without mask
    msg = 'Running Test Four: mann kendall pvalue 1.0 without mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 1.0})
    ts.append(['t_4_e.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])   
    
    # try above with default mask nc now 
    inputs.update({'in_mask_nc_file': nc_mask_file})
    
    # func: mk pvalue outside allowed without mask
    msg = 'Running Test Four: mann kendall pvalue 0.05 with mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 0.05})
    ts.append(['t_4_f.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg]) 

    # func: mk pvalue outside allowed without mask
    msg = 'Running Test Four: mann kendall pvalue 0.1 with mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 0.1})
    ts.append(['t_4_g.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg]) 

    # func: mk pvalue outside allowed without mask
    msg = 'Running Test Four: mann kendall pvalue 1.0 with mask input.'
    params = inputs.copy()
    params.update({'in_mk_pvalue': 1.0})
    ts.append(['t_4_h.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg]) 

    return ts

# %% [markdown]
# ### Test Four: Run!

# %%
# build lsit of nc corruptors and tests to iterate
nc_corrs = build_nc_corruptors(temp_nc)
tests = build_test_four_funcs(in_nc=nc_file, temp_nc=temp_nc)

# run!
run_corruptors_through_tests(in_nc=nc_file, nc_corrs=nc_corrs, tests=tests, verbose=False)
# Out:
# Corrupting NetCDF via: nc_default.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# No changes, setting up for default dataset.
# Running Test Four: default mann kendall pvalue 0.05 without mask input.
# Performing test: nc_default_t_4_def.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Four: min mann kendall pvalue 0.001 without mask input.
# Performing test: nc_default_t_4_a.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Four: max mann kendall pvalue 0.5 without mask input.
# Performing test: nc_default_t_4_b.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Four: mann kendall pvalue 0.1 without mask input.
# Performing test: nc_default_t_4_c.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Four: mann kendall pvalue 10.0 without mask input.
# Performing test: nc_default_t_4_d.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Four: mann kendall pvalue 0.0 without mask input.
# Performing test: nc_default_t_4_e.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Four: mann kendall pvalue 1.0 without mask input.
# Performing test: nc_default_t_4_e.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Four: mann kendall pvalue 0.05 with mask input.
# Performing test: nc_default_t_4_f.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Four: mann kendall pvalue 0.1 with mask input.
# Performing test: nc_default_t_4_g.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Four: mann kendall pvalue 1.0 with mask input.
# Performing test: nc_default_t_4_h.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# All tests applied to corruptor NetCDF.

# %% [markdown]
# ### Test Five: Mann-Kendall Direction

# %%
def build_test_five_funcs(in_nc, temp_nc):
    """sets up test five functions"""
    
    # set default params for tool
    inputs = {
        'in_like_nc_file': '',                # input like nc (i.e. temp nc)
        'in_mask_nc_file': '',                # input mask nc (i.e. temp mask nc)
        'out_nc_file': '',                    # output nc (i.e. t1a nc)
        'in_use_all_years': True,             # use all dates
        'in_start_year': None,                # from date
        'in_end_year': None,                  # to date
        'in_analysis_type': 'Mann-Kendall',   # trend method
        'in_mk_pvalue': 0.05,                 # man kendall pvalue
        'in_mk_direction': 'Both',            # man kendall trend direction
        'in_add_result_to_map': True,         # add result to map
    }
    
    # set up list
    ts = []

    # func: default mk direction (both) without mask
    msg = 'Running Test Five: default mann kendall direction (both) without mask input.'
    params = inputs.copy()
    params.update({'in_mk_direction': 'Both'})
    ts.append(['t_5_def.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: mk direction (increasing) without mask
    msg = 'Running Test Five: mann kendall direction Increasing without mask input.'
    params = inputs.copy()
    params.update({'in_mk_direction': 'Increasing'})
    ts.append(['t_5_a.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: mk direction (decreasing) without mask
    msg = 'Running Test Five: mann kendall direction Decreasing without mask input.'
    params = inputs.copy()
    params.update({'in_mk_direction': 'Decreasing'})
    ts.append(['t_5_b.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: mk direction (decreasing) without mask
    msg = 'Running Test Five: mann kendall direction incorrect spelling without mask input.'
    params = inputs.copy()
    params.update({'in_mk_direction': 'Increa'})
    ts.append(['t_5_c.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: mk direction (decreasing) without mask
    msg = 'Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 without mask input.'
    params = inputs.copy()
    params.update({'in_mk_direction': 'Decreasing', 'in_mk_pvalue': 0.001})
    ts.append(['t_5_d.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # try above with default mask nc now 
    inputs.update({'in_mask_nc_file': nc_mask_file})
    
    # func: default mk direction (both) with mask
    msg = 'Running Test Five: default mann kendall direction (both) with mask input.'
    params = inputs.copy()
    params.update({'in_mk_direction': 'Both'})
    ts.append(['t_5_e.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: mk direction (increasing) with mask
    msg = 'Running Test Five: mann kendall direction Increasing with mask input.'
    params = inputs.copy()
    params.update({'in_mk_direction': 'Increasing'})
    ts.append(['t_5_f.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: mk direction (decreasing) with mask
    msg = 'Running Test Five: mann kendall direction Decreasing with mask input.'
    params = inputs.copy()
    params.update({'in_mk_direction': 'Decreasing'})
    ts.append(['t_5_g.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    # func: mk direction (decreasing) with mask
    msg = 'Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 with mask input.'
    params = inputs.copy()
    params.update({'in_mk_direction': 'Decreasing', 'in_mk_pvalue': 0.001})
    ts.append(['t_5_h.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

    return ts

# %% [markdown]
# ### Test Five: Run!

# %%
# build lsit of nc corruptors and tests to iterate
nc_corrs = build_nc_corruptors(temp_nc)
tests = build_test_five_funcs(in_nc=nc_file, temp_nc=temp_nc)

# run!
run_corruptors_through_tests(in_nc=nc_file, nc_corrs=nc_corrs, tests=tests, verbose=False)
# Out:
# Corrupting NetCDF via: nc_default.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# No changes, setting up for default dataset.
# Running Test Five: default mann kendall direction (both) without mask input.
# Performing test: nc_default_t_5_def.nc.
# Running Test Five: mann kendall direction Increasing without mask input.
# Performing test: nc_default_t_5_a.nc.
# Running Test Five: mann kendall direction Decreasing without mask input.
# Performing test: nc_default_t_5_b.nc.
# Running Test Five: mann kendall direction incorrect spelling without mask input.
# Performing test: nc_default_t_5_c.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Both | Increasing | Decreasing.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 without mask input.
# Performing test: nc_default_t_5_d.nc.
# Running Test Five: default mann kendall direction (both) with mask input.
# Performing test: nc_default_t_5_e.nc.
# Running Test Five: mann kendall direction Increasing with mask input.
# Performing test: nc_default_t_5_f.nc.
# Running Test Five: mann kendall direction Decreasing with mask input.
# Performing test: nc_default_t_5_g.nc.
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 with mask input.
# Performing test: nc_default_t_5_h.nc.
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: remove_coord.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing coord: time
# Running Test Five: default mann kendall direction (both) without mask input.
# Performing test: remove_coord_t_5_def.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Increasing without mask input.
# Performing test: remove_coord_t_5_a.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing without mask input.
# Performing test: remove_coord_t_5_b.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction incorrect spelling without mask input.
# Performing test: remove_coord_t_5_c.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Both | Increasing | Decreasing.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 without mask input.
# Performing test: remove_coord_t_5_d.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: default mann kendall direction (both) with mask input.
# Performing test: remove_coord_t_5_e.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Increasing with mask input.
# Performing test: remove_coord_t_5_f.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with mask input.
# Performing test: remove_coord_t_5_g.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 with mask input.
# Performing test: remove_coord_t_5_h.nc.
# Input likelihood NetCDF must have x, y and time coords.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: remove_var.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Removing var: like
# Running Test Five: default mann kendall direction (both) without mask input.
# Performing test: remove_var_t_5_def.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Increasing without mask input.
# Performing test: remove_var_t_5_a.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing without mask input.
# Performing test: remove_var_t_5_b.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction incorrect spelling without mask input.
# Performing test: remove_var_t_5_c.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Both | Increasing | Decreasing.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 without mask input.
# Performing test: remove_var_t_5_d.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: default mann kendall direction (both) with mask input.
# Performing test: remove_var_t_5_e.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Increasing with mask input.
# Performing test: remove_var_t_5_f.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with mask input.
# Performing test: remove_var_t_5_g.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 with mask input.
# Performing test: remove_var_t_5_h.nc.
# Input likelihood NetCDF has no data/variables/bands.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_nc_vars_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting nc var data to all nan
# Running Test Five: default mann kendall direction (both) without mask input.
# Performing test: set_nc_vars_all_nan_t_5_def.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Increasing without mask input.
# Performing test: set_nc_vars_all_nan_t_5_a.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing without mask input.
# Performing test: set_nc_vars_all_nan_t_5_b.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction incorrect spelling without mask input.
# Performing test: set_nc_vars_all_nan_t_5_c.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Both | Increasing | Decreasing.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 without mask input.
# Performing test: set_nc_vars_all_nan_t_5_d.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: default mann kendall direction (both) with mask input.
# Performing test: set_nc_vars_all_nan_t_5_e.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Increasing with mask input.
# Performing test: set_nc_vars_all_nan_t_5_f.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with mask input.
# Performing test: set_nc_vars_all_nan_t_5_g.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 with mask input.
# Performing test: set_nc_vars_all_nan_t_5_h.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_nc_vars_all_zero.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting nc var data to all zero
# Running Test Five: default mann kendall direction (both) without mask input.
# Performing test: set_nc_vars_all_zero_t_5_def.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Increasing without mask input.
# Performing test: set_nc_vars_all_zero_t_5_a.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing without mask input.
# Performing test: set_nc_vars_all_zero_t_5_b.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction incorrect spelling without mask input.
# Performing test: set_nc_vars_all_zero_t_5_c.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Both | Increasing | Decreasing.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 without mask input.
# Performing test: set_nc_vars_all_zero_t_5_d.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: default mann kendall direction (both) with mask input.
# Performing test: set_nc_vars_all_zero_t_5_e.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Increasing with mask input.
# Performing test: set_nc_vars_all_zero_t_5_f.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with mask input.
# Performing test: set_nc_vars_all_zero_t_5_g.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 with mask input.
# Performing test: set_nc_vars_all_zero_t_5_h.nc.
# Input likelihood NetCDF "like" variable is empty. Please download again.
# Failed to execute (GDVSpectra_Trend).
#
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_nc_vars_random_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting 2 random times in nc var data to all nan
# ['2014-01-01T00:00:00.000000000' '2013-01-01T00:00:00.000000000']
# Running Test Five: default mann kendall direction (both) without mask input.
# Performing test: set_nc_vars_random_all_nan_t_5_def.nc.
# Running Test Five: mann kendall direction Increasing without mask input.
# Performing test: set_nc_vars_random_all_nan_t_5_a.nc.
# Running Test Five: mann kendall direction Decreasing without mask input.
# Performing test: set_nc_vars_random_all_nan_t_5_b.nc.
# Running Test Five: mann kendall direction incorrect spelling without mask input.
# Performing test: set_nc_vars_random_all_nan_t_5_c.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Both | Increasing | Decreasing.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 without mask input.
# Performing test: set_nc_vars_random_all_nan_t_5_d.nc.
# Running Test Five: default mann kendall direction (both) with mask input.
# Performing test: set_nc_vars_random_all_nan_t_5_e.nc.
# Running Test Five: mann kendall direction Increasing with mask input.
# Performing test: set_nc_vars_random_all_nan_t_5_f.nc.
# Running Test Five: mann kendall direction Decreasing with mask input.
# Performing test: set_nc_vars_random_all_nan_t_5_g.nc.
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 with mask input.
# Performing test: set_nc_vars_random_all_nan_t_5_h.nc.
# All tests applied to corruptor NetCDF.
#
#
# Corrupting NetCDF via: set_end_times_to_all_nan.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Setting end times to all nan
# Running Test Five: default mann kendall direction (both) without mask input.
# Performing test: set_end_times_to_all_nan_t_5_def.nc.
# Running Test Five: mann kendall direction Increasing without mask input.
# Performing test: set_end_times_to_all_nan_t_5_a.nc.
# Running Test Five: mann kendall direction Decreasing without mask input.
# Performing test: set_end_times_to_all_nan_t_5_b.nc.
# Running Test Five: mann kendall direction incorrect spelling without mask input.
# Performing test: set_end_times_to_all_nan_t_5_c.nc.
# Failed to execute. Parameters are not valid.
# ERROR 000800: The value is not a member of Both | Increasing | Decreasing.
# Failed to execute (GDVSpectra_Trend).
#
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 without mask input.
# Performing test: set_end_times_to_all_nan_t_5_d.nc.
# Running Test Five: default mann kendall direction (both) with mask input.
# Performing test: set_end_times_to_all_nan_t_5_e.nc.
# Running Test Five: mann kendall direction Increasing with mask input.
# Performing test: set_end_times_to_all_nan_t_5_f.nc.
# Running Test Five: mann kendall direction Decreasing with mask input.
# Performing test: set_end_times_to_all_nan_t_5_g.nc.
# Running Test Five: mann kendall direction Decreasing with low pvalue 0.001 with mask input.
# Performing test: set_end_times_to_all_nan_t_5_h.nc.
# All tests applied to corruptor NetCDF.

# %% [markdown]
# ### Test Six: Theilsen Alpha (deprecated)

# %%
# def build_test_six_funcs(in_nc, temp_nc):
#     """sets up test six functions"""
    
#     # set default params for tool
#     inputs = {
#         'in_like_nc_file': '',                        # input like nc (i.e. temp nc)
#         'in_mask_nc_file': '',                        # input mask nc (i.e. temp mask nc)
#         'out_nc_file': '',                            # output nc (i.e. t1a nc)
#         'in_from_date': None,                         # from date
#         'in_to_date': None,                           # to date
#         'in_analysis_type': 'Theilsen Slope',         # trend method
#         'in_mk_pvalue': 0.05,                         # man kendall pvalue
#         'in_mk_direction': 'Both',                    # man kendall trend direction
#         'in_ts_alpha': '',                            # theilsen alpha
#         'in_add_result_to_map': True,                 # add result to map
#     }
    
#     # set up list
#     ts = []

#     # func: default theil sen 0.95 without mask
#     msg = 'Running Test Six: default theil sen alpha without mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 0.95})
#     ts.append(['t_6_def.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

#     # func: min theil sen 0.0 without mask
#     msg = 'Running Test Six: theil sen alpha min 0.001 without mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 0.001})
#     ts.append(['t_6_a.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

#     # func: min theil sen 1.0 without mask
#     msg = 'Running Test Six: theil sen alpha max 0.999 without mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 0.999})
#     ts.append(['t_6_b.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

#     # func: random theil sen 1.0 without mask
#     msg = 'Running Test Six: theil sen alpha unallowed 1.0 without mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 1.0})
#     ts.append(['t_6_c.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

#     # func: random theil sen 1.0 without mask
#     msg = 'Running Test Six: theil sen alpha 0.5 without mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 0.5})
#     ts.append(['t_6_d.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
#     # try above with default mask nc now 
#     inputs.update({'in_mask_nc_file': nc_mask_file})
    
#     # func: default theil sen 0.95 with mask
#     msg = 'Running Test Six: default theil sen alpha with mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 0.95})
#     ts.append(['t_6_e.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

#     # func: min theil sen 0.0 with mask
#     msg = 'Running Test Six: theil sen alpha min 0.001 with mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 0.001})
#     ts.append(['t_6_f.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

#     # func: min theil sen 1.0 with mask
#     msg = 'Running Test Six: theil sen alpha max 0.999 with mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 0.999})
#     ts.append(['t_6_g.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

#     # func: random theil sen 1.0 with mask
#     msg = 'Running Test Six: theil sen alpha unallowed 0.0 with mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 0.0})
#     ts.append(['t_6_h.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])

#     # func: random theil sen 1.0 with mask
#     msg = 'Running Test Six: theil sen alpha 0.5 with mask input.'
#     params = inputs.copy()
#     params.update({'in_ts_alpha': 0.5})
#     ts.append(['t_6_i.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])



#     return ts

# %% [markdown]
# ### Test Six: Run!

# %%
# # build lsit of nc corruptors and tests to iterate
# nc_corrs = build_nc_corruptors(temp_nc)
# tests = build_test_six_funcs(in_nc=nc_file, temp_nc=temp_nc)

# # run!
# run_corruptors_through_tests(in_nc=nc_file, nc_corrs=nc_corrs, tests=tests, verbose=True)

# %% [markdown]
# ### Test Eight: Add To Map

# %%
def build_test_seven_funcs(in_nc, temp_nc):
    """sets up test seven functions"""
    
    # set default params for tool
    inputs = {
        'in_like_nc_file': '',                # input like nc (i.e. temp nc)
        'in_mask_nc_file': '',                # input mask nc (i.e. temp mask nc)
        'out_nc_file': '',                    # output nc (i.e. t1a nc)
        'in_use_all_years': True,             # use all dates
        'in_start_year': None,                # from date
        'in_end_year': None,                  # to date
        'in_analysis_type': 'Mann-Kendall',   # trend method
        'in_mk_pvalue': 0.05,                 # man kendall pvalue
        'in_mk_direction': 'Both',            # man kendall trend direction
        'in_add_result_to_map': True,         # add result to map
    }
    
    # set up list
    ts = []
            
    # func: default add result to map (True)
    msg = 'Running Test Seven: default add result to map (True).'
    params = inputs.copy()
    params.update({'in_add_result_to_map': True})
    ts.append(['t_7_def.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])
    
    # func: add result to map is False
    msg = 'Running Test Seven: add result to map is False.'
    params = inputs.copy()
    params.update({'in_add_result_to_map': False})
    ts.append(['t_7_a.nc', arcpy.GDVSpectra_Trend_toolbox , params, msg])    
     
    return ts

# %% [markdown]
# ### Test Eight: Run!

# %%
# build lsit of nc corruptors and tests to iterate
nc_corrs = build_nc_corruptors(temp_nc)
tests = build_test_seven_funcs(in_nc=nc_file, temp_nc=temp_nc)

# run!
run_corruptors_through_tests(in_nc=nc_file, nc_corrs=nc_corrs, tests=tests, verbose=False)
# Out:
# Corrupting NetCDF via: nc_default.
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# No changes, setting up for default dataset.
# Running Test Seven: default add result to map (True).
# Performing test: nc_default_t_7_def.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# Running Test Seven: add result to map is False.
# Performing test: nc_default_t_7_a.nc.
# GDVSpectra_Trend() got an unexpected keyword argument 'in_raw_nc_path'
# All tests applied to corruptor NetCDF.

# %% [markdown]
# # Quick Check

# %%
def quick():
    in_nc = r"E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_trend\inputs\dwer_1_ls_90_20_like_odc_nonagg.nc"
    out_nc = r'E:\Curtin\GDVII - General\Work Package 2\test_data\gdvspectra_likelihood\outputs\out_nc.nc'
        
    inputs = {
        'in_like_nc_file': in_nc,
        'in_mask_nc_file': '', 
        'out_nc_file': out_nc,
        'in_use_all_years': True,
        'in_start_year': None,
        'in_end_year': None,
        'in_analysis_type': 'Mann-Kendall', 
        'in_mk_pvalue': 0.05,
        'in_mk_direction': 'Both',
        'in_add_result_to_map': True,
    }
    
    arcpy.env.addOutputsToMap = True

    try:
        print('\nTest: likelihood dwer defaults')
        with io.capture_output() as cap:
            arcpy.GDVSpectra_Trend_toolbox(**inputs)
    except Exception as e:
        print(e)
        
quick()
# Out:
# Test: likelihood dwer defaults
